# %% [markdown]
# <a href="https://colab.research.google.com/github/RISHI0851/fundamentals-of-data-science/blob/main/Copy_of_module1_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
print(df.shape)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1017190820.py in <cell line: 0>()
# ----> 1 print(df.shape)
#       2 print(df.head())
#       3
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("/content/heart (3).csv")  # Use the exact file name shown in left Files panel
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-327731794.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("/content/heart (3).csv")  # Use the exact file name shown in left Files panel
#       4 df.head()
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/heart.csv")  # use file path
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2853274171.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("/content/heart.csv")  # use file path
#       3 df.head()
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/heart.csv")  # use file path
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2853274171.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("/content/heart.csv")  # use file path
#       3 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/heart (3).csv")
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       289 non-null    int64
#  1   sex       289 non-null    int64
#  2   cp        289 non-null    int64
#  3   trtbps    289 non-null    int64
#  4   chol      289 non-null    int64
#  5   fbs       289 non-null    int64
#  6   restecg   289 non-null    int64
#  7   thalachh  289 non-null    int64
#  8   exng      289 non-null    int64
#  9   oldpeak   289 non-null    float64
#  10  slp       289 non-null    int64
#  11  caa       289 non-null    int64
#  12  thall     289 non-null    int64
#  13  output    289 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 31.7 KB

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  289.000000  289.000000  289.000000  289.000000  289.000000  289.000000
# mean    54.010381    0.678201    1.020761  131.377163  247.961938    0.145329
# std      9.132316    0.467977    1.027192   17.518432   51.596208    0.353043
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  212.000000    0.000000
# 50%     54.000000    1.000000    1.000000  130.000000  243.000000    0.000000
# 75%     60.000000    1.000000    2.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  289.000000  289.000000  289.000000  289.000000  289.000000  289.000000
# mean     0.515571  150.231834    0.318339    1.007612    1.418685    0.712803
# ...

# %%
df['target'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1476409753.py in <cell line: 0>()
# ----> 1 df['target'].value_counts()
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df['output'].value_counts()
# Out:
# output
# 1    165
# 0    124
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=df['output'])
plt.title("Heart Disease Count (1 = Disease, 0 = No Disease)")
plt.show()

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Features")
plt.show()

# %%
print(df.shape)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2382623769.py in <cell line: 0>()
# ----> 1 print(df.shape)
#       2 print(df.head())
#
# NameError: name 'df' is not defined

# %%
# Step 1: Splitting the data into Features (X) and Target (y)
X = df.drop('output', axis=1)   # All columns except target
y = df['output']                # Target column

from sklearn.model_selection import train_test_split

# 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1778950847.py in <cell line: 0>()
#       1 # Step 1: Splitting the data into Features (X) and Target (y)
# ----> 2 X = df.drop('output', axis=1)   # All columns except target
#       3 y = df['output']                # Target column
#       4
#       5 from sklearn.model_selection import train_test_split
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("/content/heart (3).csv")  # ← Replace with your exact file name
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
print(df.shape)
print(df.head())
# Out:
# (289, 14)
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
X = df.drop('output', axis=1)
y = df['output']

# %%
# Step 1: Splitting the data into Features (X) and Target (y)
X = df.drop('output', axis=1)   # All columns except target
y = df['output']                # Target column

from sklearn.model_selection import train_test_split

# 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (231, 13)
# Testing set shape: (58, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Predictions on test data
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy, 4))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm)

y_proba = rf.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_proba)
print("\nROC AUC Score:", round(roc_auc, 4))
# Out:
# Accuracy: 0.8448
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        25
#            1       0.82      0.94      0.87        33
#
#     accuracy                           0.84        58
#    macro avg       0.86      0.83      0.84        58
# weighted avg       0.85      0.84      0.84        58
#
#
# Confusion Matrix:
#  [[18  7]
#  [ 2 31]]
#
# ROC AUC Score: 0.9285

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

# Confusion Matrix Heatmap
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve Plot
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label="ROC AUC = " + str(round(roc_auc, 4)))
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Feature Importance
import pandas as pd

feat_imp = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
print(feat_imp.head(10))

plt.figure(figsize=(8,6))
feat_imp.plot(kind='bar')
plt.title("Feature Importance")
plt.ylabel("Importance Score")
plt.show()
# Out:
# oldpeak     0.137277
# thalachh    0.118315
# cp          0.114591
# thall       0.106573
# caa         0.092753
# chol        0.090045
# trtbps      0.072322
# age         0.071754
# exng        0.064112
# slp         0.058637
# dtype: float64

# %%
new_patient = np.array([[63,1,3,145,233,1,0,150,0,2.3,0,0,1]])  # Example

prediction = rf.predict(new_patient)
probability = rf.predict_proba(new_patient)[:,1]

print("Prediction (1 = Disease, 0 = No Disease):", prediction[0])
print("Probability of Disease:", round(probability[0], 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2395200852.py in <cell line: 0>()
# ----> 1 new_patient = np.array([[63,1,3,145,233,1,0,150,0,2.3,0,0,1]])  # Example
#       2
#       3 prediction = rf.predict(new_patient)
#       4 probability = rf.predict_proba(new_patient)[:,1]
#       5
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
new_patient = np.array([[63,1,3,145,233,1,0,150,0,2.3,0,0,1]])  # Example

prediction = rf.predict(new_patient)
probability = rf.predict_proba(new_patient)[:,1]

print("Prediction (1 = Disease, 0 = No Disease):", prediction[0])
print("Probability of Disease:", round(probability[0], 4))
# Out:
# Prediction (1 = Disease, 0 = No Disease): 1
# Probability of Disease: 0.54
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import joblib

joblib.dump(rf, "heart_rf_model.joblib")
print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
y_proba = rf.predict_proba(X_test)[:,1]
roc_auc = roc_auc_score(y_test, y_proba)
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.plot(fpr, tpr, label=f"ROC AUC = {roc_auc:.3f}")
plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        25
#            1       0.82      0.94      0.87        33
#
#     accuracy                           0.84        58
#    macro avg       0.86      0.83      0.84        58
# weighted avg       0.85      0.84      0.84        58
